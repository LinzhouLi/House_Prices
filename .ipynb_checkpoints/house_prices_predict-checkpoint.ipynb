# %%
import numpy as np
import pandas as pd
import torch
from torch import nn
from d2l import torch as d2l

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %%
print(train_data.shape)
print(test_data.shape)
# Out:
# (47439, 41)
# (31626, 40)

# %%
#删除部分列
train_data.drop(['Id','Sold Price', 'Address','Elementary School','Middle School','High School','Zip','State','Annual tax amount','Parking features','Laundry features','Cooling features','Heating features'], axis=1, inplace=True)
test_data.drop(['Id', 'Address','Elementary School','Middle School','High School','Zip','State','Annual tax amount','Parking features','Laundry features','Cooling features','Heating features'], axis=1, inplace=True)
all_features = pd.concat((train_data, test_data))

all_features.head()
# Out:
#                                              Summary          Type  \
# 0  540 Pine Ln, Los Altos, CA 94022 is a single f...  SingleFamily
# 1  HURRY, HURRY.......Great house 3 bed and 2 bat...  SingleFamily
# 2  'THE PERFECT CABIN TO FLIP!  Strawberry deligh...  SingleFamily
# 3  Rare 2-story Gated 5 bedroom Modern Mediterran...  SingleFamily
# 4  Beautiful 200 acre ranch land with several pas...    VacantLand
#
#    Year built                                       Heating  \
# 0      1969.0  Heating - 2+ Zones, Central Forced Air - Gas
# 1      1926.0                                   Combination
# 2      1958.0                                    Forced air
# 3      1947.0                                       Central
# 4         NaN                                           NaN
#
#                                              Cooling  \
# 0    Multi-Zone, Central AC, Whole House / Attic Fan
# 1  Wall/Window Unit(s), Evaporative Cooling, See ...
# 2                                                NaN
# 3                                        Central Air
# 4                                                NaN
#
#                                          Parking     Lot  \
# 0             Garage, Garage - Attached, Covered     1.0
# 1                       Detached Carport, Garage  4047.0
# 2                                       0 spaces  9147.0
# 3  Detached Carport, Driveway, Garage - Two Door     NaN
# 4                                       0 spaces     NaN
#
#                                             Bedrooms  Bathrooms  \
# 0  Ground Floor Bedroom, Master Bedroom on Ground...        0.0
# 1                                                  3        2.0
# 2                                                  2        3.0
# 3                                                  5        3.0
# 4                                                NaN        NaN
#
#    Full bathrooms  ...  High School Score  High School Distance  \
# 0             NaN  ...                8.0                   1.3
# 1             2.0  ...                2.0                   1.3
# 2             1.0  ...                NaN                  10.1
# 3             3.0  ...                8.0                   0.2
# 4             NaN  ...                6.0                  10.6
#
#                  Flooring                                Appliances included  \
# 0  Tile, Hardwood, Carpet  Dishwasher, Dryer, Garbage disposal, Microwave...
# 1                     NaN                                                NaN
# 2                     NaN                                                NaN
# 3              Wood, Tile                                         Dishwasher
# 4                     NaN                                                NaN
#
#    Tax assessed value   Listed On  Listed Price  Last Sold On  \
# 0            886486.0  2019-10-24     4198000.0           NaN
# 1            505000.0  2019-10-16      525000.0    2019-08-30
# 2             49627.0  2019-08-25      180000.0           NaN
# 3           1775000.0  2019-10-24     1895000.0    2016-08-30
# 4                 NaN  2019-06-07     1595000.0    2016-06-27
#
#    Last Sold Price         City
# 0              NaN    Los Altos
# 1         328000.0  Los Angeles
# 2              NaN   Strawberry
# 3        1500000.0  Culver City
# 4         900000.0      Creston
#
# [5 rows x 28 columns]

# %%
#将Summary转化为int
all_features.iloc[:,0] = all_features.iloc[:,0].apply(
    lambda x: len(str(x)))

# %%
#将日期转化为int
all_features['Listed On'] = all_features['Listed On'].apply(pd.to_datetime,format='%Y-%m-%d %H:%M:%S.%f')
all_features['Last Sold On'] = all_features['Last Sold On'].apply(pd.to_datetime,format='%Y-%m-%d %H:%M:%S.%f')

all_features['Listed On'] = all_features['Listed On'].apply(
    lambda x: (x.year-2000)*12 + x.month)
all_features['Last Sold On'] = all_features['Last Sold On'].apply(
    lambda x: (x.year-2000)*12 + x.month)

# %%
#将Bedrooms转化为int
def n_bedrooms(s):
    if type(s) is float:
        return s
    else:
        l = len(s)
        if l <= 2:
            return int(s)
        s = s.lower()
        l1 = s.count(',') + s.count('/')
        l2 = s.count('more')
        return l1 + 1 + int(1.5 * l2)


all_features['Bedrooms'] = all_features['Bedrooms'].apply(
    lambda s: n_bedrooms(s))

# %%
#Heating,Cooling,Parking,Type,Flooring
def trans_1(s):
    if type(s) is float:
        return 'none'
    l = s.find(',')
    if l == -1:
        return s
    else:
        s =  s[:l]
        return s.lower()
    
def trans_2(s):
    if type(s) is float:
        return s
    l = s.find(',')
    if l == -1:
        return s
    else:
        s =  s[:l]
        return s.lower()


all_features['Heating'] = all_features['Heating'].apply(
    lambda s: trans_1(s))
all_features['Cooling'] = all_features['Cooling'].apply(
    lambda s: trans_1(s))
all_features['Parking'] = all_features['Parking'].apply(
    lambda s: trans_1(s))

all_features['Type'] = all_features['Type'].apply(
    lambda s: trans_2(s))
all_features['Flooring'] = all_features['Flooring'].apply(
    lambda s: trans_2(s))

# %%
#Appliances included转化为int
def trans_3(s):
    if type(s) is float:
        return 0
    else:
        return s.count(',') + 1
    
all_features['Appliances included'] = all_features['Appliances included'].apply(
    lambda s: trans_3(s))

# %%
numeric_features = all_features.dtypes[all_features.dtypes != 'object'].index
all_features[numeric_features] = all_features[numeric_features].apply(
    lambda x: (x - x.mean()) / (x.std()))
all_features[numeric_features] = all_features[numeric_features].fillna(0)

object_features = all_features.dtypes[all_features.dtypes == 'object'].index
all_features[object_features] = all_features[object_features].apply(lambda x: x.astype(str).str.lower())

all_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79065 entries, 0 to 31625
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Summary                      79065 non-null  float64
#  1   Type                         79065 non-null  object
#  2   Year built                   79065 non-null  float64
#  3   Heating                      79065 non-null  object
#  4   Cooling                      79065 non-null  object
#  5   Parking                      79065 non-null  object
#  6   Lot                          79065 non-null  float64
#  7   Bedrooms                     79065 non-null  float64
#  8   Bathrooms                    79065 non-null  float64
#  9   Full bathrooms               79065 non-null  float64
#  10  Total interior livable area  79065 non-null  float64
#  11  Total spaces                 79065 non-null  float64
#  12  Garage spaces                79065 non-null  float64
#  13  Region                       79065 non-null  object
#  14  Elementary School Score      79065 non-null  float64
#  15  Elementary School Distance   79065 non-null  float64
#  16  Middle School Score          79065 non-null  float64
#  17  Middle School Distance       79065 non-null  float64
#  18  High School Score            79065 non-null  float64
#  19  High School Distance         79065 non-null  float64
#  20  Flooring                     79065 non-null  object
#  21  Appliances included          79065 non-null  float64
#  22  Tax assessed value           79065 non-null  float64
#  23  Listed On                    79065 non-null  float64
#  24  Listed Price                 79065 non-null  float64
#  25  Last Sold On                 79065 non-null  float64
#  26  Last Sold Price              79065 non-null  float64
#  27  City                         79065 non-null  object
# dtypes: float64(21), object(7)
# memory usage: 17.5+ MB

# %%
all_features
# Out:
#         Summary          Type    Year built             Heating  \
# 0     -1.123595  singlefamily  4.911225e-02  heating - 2+ zones
# 1     -1.115751  singlefamily -2.882172e-01         combination
# 2      0.978606  singlefamily -3.718133e-02          forced air
# 3      0.445212  singlefamily -1.234749e-01             central
# 4     -1.097448    vacantland -8.465954e-16                none
# ...         ...           ...           ...                 ...
# 31621 -0.530063  singlefamily  4.413558e-01             radiant
# 31622 -0.171852  singlefamily  5.695712e-02          forced air
# 31623 -0.647723    vacantland -8.465954e-16                none
# 31624 -0.898732     townhouse  1.667853e-01        fireplace(s)
# 31625 -1.134053     townhouse  2.373891e-01          forced air
#
#                    Cooling             Parking           Lot      Bedrooms  \
# 0               multi-zone              garage -2.195468e-02  1.587374e+00
# 1      wall/window unit(s)    detached carport -2.171401e-02 -1.197358e-02
# 2                     none            0 spaces -2.141064e-02 -8.116474e-01
# 3              central air    detached carport  3.734898e-18  1.587374e+00
# 4                     none            0 spaces  3.734898e-18  4.741178e-17
# ...                    ...                 ...           ...           ...
# 31621     air conditioning            attached  3.734898e-18  1.587374e+00
# 31622                 none               guest -2.185802e-02 -8.116474e-01
# 31623                 none            0 spaces  3.734898e-18  4.741178e-17
# 31624                 none            assigned  3.734898e-18 -1.197358e-02
# 31625          central air  garage door opener  3.734898e-18  7.877002e-01
#
#           Bathrooms  Full bathrooms  ...  High School Score  \
# 0     -2.132244e+00   -1.587880e-16  ...       9.787579e-01
# 1     -3.489175e-01   -1.163619e-01  ...      -2.212942e+00
# 2      5.427458e-01   -1.276596e+00  ...      -6.436064e-17
# 3      5.427458e-01    1.043872e+00  ...       9.787579e-01
# 4     -8.938577e-17   -1.587880e-16  ...      -8.514215e-02
# ...             ...             ...  ...                ...
# 31621  3.217736e+00   -1.587880e-16  ...       4.468079e-01
# 31622 -3.489175e-01   -1.276596e+00  ...      -6.436064e-17
# 31623 -8.938577e-17   -1.587880e-16  ...      -6.170922e-01
# 31624  5.427458e-01   -1.163619e-01  ...      -8.514215e-02
# 31625 -3.489175e-01   -1.587880e-16  ...      -1.680992e+00
#
#        High School Distance  Flooring Appliances included  Tax assessed value  \
# 0                 -0.333677      tile            0.949948        2.030697e-01
# 1                 -0.333677       nan           -1.074844       -1.825415e-01
# 2                  2.465363       nan           -1.074844       -6.428388e-01
# 3                 -0.683557      wood           -0.737379        1.101192e+00
# 4                  2.624399       nan           -1.074844        1.798900e-17
# ...                     ...       ...                 ...                 ...
# 31621              0.938614     mixed            1.624878        4.178429e+00
# 31622             -0.460906  laminate            0.275017       -3.929737e-01
# 31623              0.429697       nan           -1.074844        1.798900e-17
# 31624             -0.206448  laminate           -0.062448       -3.551107e-01
# 31625             -0.619943      wood           -1.074844       -1.439790e-01
#
#        Listed On  Listed Price  Last Sold On  Last Sold Price          City
# 0      -0.418634      1.407144 -8.539397e-17     1.635204e-17     los altos
# 1      -0.418634     -0.282410  1.305991e+00    -4.613161e-01   los angeles
# 2      -0.542590     -0.441107 -8.539397e-17     1.635204e-17    strawberry
# 3      -0.418634      0.347781  7.710818e-01     1.005130e+00   culver city
# 4      -0.666545      0.209783  7.413646e-01     2.543895e-01       creston
# ...          ...           ...           ...              ...           ...
# 31621   0.325098      3.386034  5.779200e-01     2.487590e-01     yuba city
# 31622   0.201143     -0.372108  1.543729e+00    -4.613161e-01     oceanside
# 31623  -5.562786     -0.320129 -8.539397e-17     1.635204e-17       la mesa
# 31624   0.139165     -0.319209  1.543729e+00    -2.836409e-01     san diego
# 31625  -1.472256     -0.266770  1.112830e+00    -2.054388e-01  baldwin park
#
# [79065 rows x 28 columns]

# %%
all_features = pd.get_dummies(all_features, dummy_na=True)
all_features.shape
# Out:
# (79065, 2907)
